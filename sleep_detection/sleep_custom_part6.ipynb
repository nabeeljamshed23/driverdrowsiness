# %%
import numpy as np 
import pandas as pd 
import os
import tensorflow as tf

from glob import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
from PIL import Image

# %%
X = []
Y = []

for i in tqdm(glob('../eye_dataset/kaggle/open_eye/*')[0:8000]):
    temp = np.array(Image.open(i).resize((64,64)))
    X.append(temp)
    Y.append(1)
    
for i in tqdm(glob('../eye_dataset/kaggle/closed_eye/*')[0:8000]):
    temp = np.array(Image.open(i).resize((64,64)))
    X.append(temp)
    Y.append(0)
# Out:
# 100%|██████████| 8000/8000 [00:03<00:00, 2533.48it/s]
# 100%|██████████| 8000/8000 [00:03<00:00, 2111.12it/s]

# %%
# Pre Processing
X = np.array(X)
X = X/255.0
Y = np.array(Y)

# %%
X = np.expand_dims(X,-1)

# %%
# test-train split 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print(y_train.size)
print(y_test.size)
# Out:
# 12800
# 3200

# %%
# Model Building 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, BatchNormalization, MaxPooling2D,Dropout, Flatten

model = tf.keras.models.Sequential([
    Input(shape=(64, 64, 1)),

    Conv2D(filters = 64, kernel_size = 5, strides = 1, activation = 'relu'),
    Conv2D(filters = 64, kernel_size = 5, strides = 1, activation = 'relu', use_bias=False),
    BatchNormalization(),
    MaxPooling2D(strides = 2),
    Dropout(0.3),

    Conv2D(filters = 32, kernel_size = 3, strides = 1, activation = 'relu'),
    Conv2D(filters = 32, kernel_size = 3, strides = 1, activation = 'relu', use_bias=False),
    BatchNormalization(),
    MaxPooling2D(strides = 2),
    Dropout(0.3),

    Flatten(),
    Dense(units  = 256, activation = 'relu', use_bias=False),
    BatchNormalization(),

    Dense(units = 128, use_bias=False, activation = 'relu'),

    Dense(units = 64, use_bias=False, activation = 'relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(units = 1, activation = 'sigmoid')
])
# Out:
# 2023-11-21 20:05:54.752969: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-11-21 20:05:54.753054: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-11-21 20:05:54.753074: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-11-21 20:05:54.753536: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-11-21 20:05:54.753933: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 64)        1664
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)        102400
#
#  batch_normalization (Batch  (None, 56, 56, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 28, 28, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        18464
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        9216
#
#  batch_normalization_1 (Bat  (None, 24, 24, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 32)        0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179648
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_1 (Dense)             (None, 128)               32768
#
#  dense_2 (Dense)             (None, 64)                8192
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1354081 (5.17 MB)
# Trainable params: 1353249 (5.16 MB)
# Non-trainable params: 832 (3.25 KB)
# _________________________________________________________________

# %%
#  Compiling 
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='sleep_model_6.h5',
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose =1)

# %%
# training the model 
model.fit(x_train, y_train, validation_split=0.2, epochs=30, batch_size=32, callbacks=callback)
# Out:
# Epoch 1/30
# 2023-11-21 20:07:59.272988: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 320/320 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.9118
# 2023-11-21 20:08:53.415449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.34859, saving model to sleep_model_6.h5
# 320/320 [==============================] - 61s 136ms/step - loss: 0.2246 - accuracy: 0.9118 - val_loss: 1.3486 - val_accuracy: 0.5820
# Epoch 2/30
#   1/320 [..............................] - ETA: 25s - loss: 0.2232 - accuracy: 0.9062
# /Users/umarkhan/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 320/320 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9561
# Epoch 2: val_loss improved from 1.34859 to 0.32688, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 124ms/step - loss: 0.1239 - accuracy: 0.9561 - val_loss: 0.3269 - val_accuracy: 0.8590
# Epoch 3/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9674
# Epoch 3: val_loss improved from 0.32688 to 0.20585, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 125ms/step - loss: 0.0909 - accuracy: 0.9674 - val_loss: 0.2059 - val_accuracy: 0.9148
# Epoch 4/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9732
# Epoch 4: val_loss improved from 0.20585 to 0.14724, saving model to sleep_model_6.h5
# 320/320 [==============================] - 39s 123ms/step - loss: 0.0769 - accuracy: 0.9732 - val_loss: 0.1472 - val_accuracy: 0.9473
# Epoch 5/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9778
# Epoch 5: val_loss did not improve from 0.14724
# 320/320 [==============================] - 39s 123ms/step - loss: 0.0614 - accuracy: 0.9778 - val_loss: 0.2653 - val_accuracy: 0.8945
# Epoch 6/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9818
# Epoch 6: val_loss improved from 0.14724 to 0.07190, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0521 - accuracy: 0.9818 - val_loss: 0.0719 - val_accuracy: 0.9734
# Epoch 7/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9859
# Epoch 7: val_loss did not improve from 0.07190
# 320/320 [==============================] - 39s 123ms/step - loss: 0.0401 - accuracy: 0.9859 - val_loss: 0.0826 - val_accuracy: 0.9691
# Epoch 8/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9866
# Epoch 8: val_loss did not improve from 0.07190
# 320/320 [==============================] - 39s 123ms/step - loss: 0.0398 - accuracy: 0.9866 - val_loss: 0.5610 - val_accuracy: 0.7730
# Epoch 9/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9857
# Epoch 9: val_loss did not improve from 0.07190
# 320/320 [==============================] - 40s 123ms/step - loss: 0.0385 - accuracy: 0.9857 - val_loss: 0.1974 - val_accuracy: 0.9207
# Epoch 10/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9891
# Epoch 10: val_loss improved from 0.07190 to 0.06434, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 126ms/step - loss: 0.0317 - accuracy: 0.9891 - val_loss: 0.0643 - val_accuracy: 0.9809
# Epoch 11/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9899
# Epoch 11: val_loss improved from 0.06434 to 0.03609, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.0361 - val_accuracy: 0.9867
# Epoch 12/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9876
# Epoch 12: val_loss did not improve from 0.03609
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0360 - accuracy: 0.9876 - val_loss: 0.0689 - val_accuracy: 0.9797
# Epoch 13/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9927
# Epoch 13: val_loss did not improve from 0.03609
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0234 - accuracy: 0.9927 - val_loss: 0.0908 - val_accuracy: 0.9656
# Epoch 14/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9831
# Epoch 14: val_loss did not improve from 0.03609
# 320/320 [==============================] - 39s 123ms/step - loss: 0.0470 - accuracy: 0.9831 - val_loss: 0.0820 - val_accuracy: 0.9758
# Epoch 15/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9913
# Epoch 15: val_loss did not improve from 0.03609
# 320/320 [==============================] - 41s 127ms/step - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.3849 - val_accuracy: 0.8434
# Epoch 16/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9937
# Epoch 16: val_loss did not improve from 0.03609
# 320/320 [==============================] - 44s 137ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.1622 - val_accuracy: 0.9320
# Epoch 17/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9943
# Epoch 17: val_loss did not improve from 0.03609
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.1447 - val_accuracy: 0.9449
# Epoch 18/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9929
# Epoch 18: val_loss did not improve from 0.03609
# 320/320 [==============================] - 38s 119ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.0605 - val_accuracy: 0.9793
# Epoch 19/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9955
# Epoch 19: val_loss did not improve from 0.03609
# 320/320 [==============================] - 47s 146ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0419 - val_accuracy: 0.9879
# Epoch 20/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9937
# Epoch 20: val_loss did not improve from 0.03609
# 320/320 [==============================] - 41s 129ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0498 - val_accuracy: 0.9832
# Epoch 21/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9934
# Epoch 21: val_loss did not improve from 0.03609
# 320/320 [==============================] - 40s 124ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.0855 - val_accuracy: 0.9719
# Epoch 22/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9941
# Epoch 22: val_loss did not improve from 0.03609
# 320/320 [==============================] - 40s 125ms/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 0.0569 - val_accuracy: 0.9789
# Epoch 23/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9957
# Epoch 23: val_loss improved from 0.03609 to 0.03442, saving model to sleep_model_6.h5
# 320/320 [==============================] - 40s 125ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0344 - val_accuracy: 0.9875
# Epoch 24/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9957
# Epoch 24: val_loss did not improve from 0.03442
# 320/320 [==============================] - 40s 125ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0443 - val_accuracy: 0.9875
# Epoch 25/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9929
# Epoch 25: val_loss did not improve from 0.03442
# 320/320 [==============================] - 41s 130ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0383 - val_accuracy: 0.9883
# Epoch 26/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9940
# Epoch 26: val_loss did not improve from 0.03442
# 320/320 [==============================] - 40s 125ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0379 - val_accuracy: 0.9887
# Epoch 27/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9964
# Epoch 27: val_loss did not improve from 0.03442
# 320/320 [==============================] - 41s 127ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0952 - val_accuracy: 0.9730
# Epoch 28/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9970
# Epoch 28: val_loss improved from 0.03442 to 0.03326, saving model to sleep_model_6.h5
# 320/320 [==============================] - 42s 130ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0333 - val_accuracy: 0.9895
# Epoch 29/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9958
# Epoch 29: val_loss improved from 0.03326 to 0.03023, saving model to sleep_model_6.h5
# 320/320 [==============================] - 42s 130ms/step - loss: 0.0109 - accuracy: 0.9958 - val_loss: 0.0302 - val_accuracy: 0.9883
# Epoch 30/30
# 320/320 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9964
# Epoch 30: val_loss did not improve from 0.03023
# 320/320 [==============================] - 40s 126ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0598 - val_accuracy: 0.9816

# %%
# evaluating the model 
from keras.models import load_model
best_model = load_model('sleep_model_6.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 2023-11-22 01:43:17.470814: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 100/100 [==============================] - 7s 35ms/step - loss: 0.0322 - accuracy: 0.9900
# [0.03224075585603714, 0.9900000095367432]

# %%
# accuracy 
fig1 = plt.gcf()
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.axis(ymin=0,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
# loss
fig1 = plt.gcf()
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.axis(ymin=0,ymax=1.4)
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
# confusion matrix 
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(15, 5))

preds = best_model.predict(x_test)
preds = (preds >= 0.5).astype(np.int32)
cm = confusion_matrix(y_test, preds)
df_cm = pd.DataFrame(cm, index=['Open(1)', 'Closed(0)'], columns=['Open(1)', 'Closed(0)'])
plt.subplot(121)
plt.title("Confusion matrix\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")
# Out:
# 100/100 [==============================] - 3s 32ms/step
# Text(0.5, 25.722222222222214, 'Actual')

# %%
# | TP | FP |
# | FN | TN |
tp = cm[0][0]
fn = cm[1][0]
fp = cm[0][1]
tn = cm[1][1]
accuracy = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1 = 2*precision*recall/(precision+recall)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.99
# Precision:  0.9918546365914787
# Recall:  0.9881398252184769
# F1 Score:  0.989993746091307
